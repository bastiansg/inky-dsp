# %%
import random

from glob import glob

from inky_dsp.pipelines import display_image
from inky_dsp.buttons import InkyButtons, ButtonMap

# %%
image_paths = glob("/resources/test-images/*.jpg")
print(f"image_paths: {len(image_paths)}")

# %%
# image_path = random.choice(image_paths)
# display_image(file_path=image_path)

# %%
buttons = InkyButtons(button_map=ButtonMap())

# %%
buttons.start()

# %%
buttons.stop()
